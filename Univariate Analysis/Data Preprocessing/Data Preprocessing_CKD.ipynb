# %%
import pandas as pd

# %%
dataset=pd.read_csv("kidney_disease.csv")

# %%
dataset
# Out:
#         id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  138.0  4.4  15.4
# 1      1.0   7.0  50.0  1.020  4.0  0.0  121.0  18.0  0.8  138.0  4.4  11.3
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  138.0  4.4   9.6
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  138.0  4.4  11.6
# ..     ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
def QuanQual(dataset):
    Quan=[]
    Qual=[]
    for ColumnName in dataset.columns:
        #print(ColumnName)
        if (dataset[ColumnName].dtypes=="O"):
            #print("Qual")
            Qual.append(ColumnName)
        else:
            #print("Quan")
            Quan.append(ColumnName)
    return Quan,Qual

# %%
Quan,Qual = QuanQual(dataset)

# %%
Quan,Qual
# Out:
# (['id',
#   'age',
#   'bp',
#   'sg',
#   'al',
#   'su',
#   'bgr',
#   'bu',
#   'sc',
#   'sod',
#   'pot',
#   'hemo'],
#  ['rbc',
#   'pc',
#   'pcc',
#   'ba',
#   'pcv',
#   'wc',
#   'rc',
#   'htn',
#   'dm',
#   'cad',
#   'appet',
#   'pe',
#   'ane',
#   'classification'])

# %%
dataset[Quan]
# Out:
#       id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2    NaN  NaN  15.4
# 1      1   7.0  50.0  1.020  4.0  0.0    NaN  18.0  0.8    NaN  NaN  11.3
# 2      2  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8    NaN  NaN   9.6
# 3      3  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4    NaN  NaN  11.6
# ..   ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
dataset[Qual]
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0       NaN    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1       NaN    normal  notpresent  notpresent  38  6000  NaN   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  NaN   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='median')
imp.fit(dataset[Quan])
dataset = imp.fit_transform(dataset[Quan])

# %%
dataset
# Out:
# array([[  0. ,  48. ,  80. , ..., 138. ,   4.4,  15.4],
#        [  1. ,   7. ,  50. , ..., 138. ,   4.4,  11.3],
#        [  2. ,  62. ,  80. , ..., 138. ,   4.4,   9.6],
#        ...,
#        [397. ,  12. ,  80. , ..., 137. ,   4.4,  15.8],
#        [398. ,  17. ,  60. , ..., 135. ,   4.9,  14.2],
#        [399. ,  58. ,  80. , ..., 141. ,   3.5,  15.8]], shape=(400, 12))

# %%
dataset = pd.DataFrame(dataset, columns=Quan)

# %%
dataset
# Out:
#         id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  138.0  4.4  15.4
# 1      1.0   7.0  50.0  1.020  4.0  0.0  121.0  18.0  0.8  138.0  4.4  11.3
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  138.0  4.4   9.6
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  138.0  4.4  11.6
# ..     ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# id      0
# age     0
# bp      0
# sg      0
# al      0
# su      0
# bgr     0
# bu      0
# sc      0
# sod     0
# pot     0
# hemo    0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='Unknown')
imp.fit(dataset[Qual])
dataset = imp.fit_transform(dataset[Qual])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 4
#       2 from sklearn.impute import SimpleImputer
#       3 imp = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='Unknown')
# ----> 4 imp.fit(dataset[Qual])
#       5 dataset = imp.fit_transform(dataset[Qual])
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
# ...
