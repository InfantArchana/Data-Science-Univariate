# %%
import pandas as pd

# %%
dataset = pd.read_csv("Preprocessed_Placement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
# To check missing values

dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
import seaborn as sns

# %%
# To view the data distribution of column "ssc_p" using displot() from seaborn library
# It is used to analyse how the data is distributed.

sns.distplot(dataset["ssc_p"])
# Out:
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/4236017307.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["ssc_p"])
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
# `distplot` is a deprecated function, so used displot (a figure-level function with similar flexibility)

sns.displot(dataset["ssc_p"], kde=True)

# %%
# Histogram - Frequncy
# `distplot` is a deprecated function, so used histplot (an axes-level function for histograms)

sns.histplot(dataset["ssc_p"], kde=True)
# Out:
# <Axes: xlabel='ssc_p', ylabel='Count'>

# %% [markdown]
# # Probability Density Function (PDF)

# %%
# Below is the function to calculate PDF for a particular range in dataset

def get_pdf_probability(dataset,startrange,endrange):
    # import libraries
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns

    # Distribution plot
    axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
    #axis = sns.histplot(dataset, kde=True, color='Green')
    pyplot.axvline(startrange, color='Red')
    pyplot.axvline(endrange, color='Red')

    # generate a sample data
    sample = dataset
    
    # calculate parameters - Mean and Standard Deviation
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    
    # define the normal distribution of the data
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob = sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    
    return prob

# %%
get_pdf_probability(dataset["ssc_p"],60,80)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(60,80):0.6346413295441957
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# np.float64(0.6346413295441957)

# %%
get_pdf_probability(dataset["ssc_p"],40,50)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(40,50):0.04489259448345172
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# np.float64(0.04489259448345172)

# %%
get_pdf_probability(dataset["ssc_p"],40,40)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(40,40):0
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# 0

# %%
get_pdf_probability(dataset["hsc_p"],40,50)
# Out:
# Mean=66.333, Standard Deviation=10.898
# The area between range(40,50):0.05426082914305822
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# np.float64(0.05426082914305822)

# %%
get_pdf_probability(dataset["degree_p"],70,80)
# Out:
# Mean=66.370, Standard Deviation=7.359
# The area between range(70,80):0.2981022867238889
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# np.float64(0.2981022867238889)

# %%
get_pdf_probability(dataset["etest_p"],60,80)
# Out:
# Mean=72.101, Standard Deviation=13.276
# The area between range(60,80):0.5401819748989753
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# np.float64(0.5401819748989753)

# %%
get_pdf_probability(dataset["mba_p"],40,50)
# Out:
# Mean=62.278, Standard Deviation=5.833
# The area between range(40,50):0.014099792014858635
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# np.float64(0.014099792014858635)

# %%
get_pdf_probability(dataset["salary"],200000,400000)
# Out:
# /var/folders/tk/w8w2mxns4s16myv7xnc6y6z40000gp/T/ipykernel_2150/2965793280.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(dataset, kde=True, kde_kws={'color':'blue'}, color='Green')
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(200000,400000):0.3999468571033832
# np.float64(0.3999468571033832)

# %% [markdown]
# # Cumulative Density Function (CDF)

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(dataset['ssc_p'])
ecdf(80)
# Out:
# np.float64(0.8651162790697674)

# %%
#!pip install statsmodels

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(dataset['ssc_p'])
ecdf(80)
# Out:
# np.float64(0.8651162790697674)

# %% [markdown]
# # Standard Normal Distribution (SND)

# %%
def stdNBgraph(dataset):

    # Calculate Mean and Standard Deviation
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    # Calculate the z-score
    z_score = [((x-mean)/std) for x in values]

    #Plotting
    import seaborn as sns
    sns.displot(z_score,kde=True)

    #z_score.std()
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["ssc_p"])
