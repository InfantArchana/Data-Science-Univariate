# %%
import pandas as pd

# %%
dataset = pd.read_csv("Preprocessed_Placement.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no       0
# ssc_p       0
# hsc_p       0
# degree_p    0
# etest_p     0
# mba_p       0
# salary      0
# dtype: int64
