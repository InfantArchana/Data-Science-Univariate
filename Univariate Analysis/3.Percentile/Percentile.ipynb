# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info() # dataset.info() shows the detailed information and properties of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#EXPECTED OUTPUT
#Quan = ["ssc_p ","hsc_p","degree_p"," etest_p","mba_p","salary"] # CONTINOUS VALUE
#Qual = ["gender","ssc_b","hsc_b","hsc_s","degree_t","workex","specialisation","status"] # NOMINAL VALUE

# %%
# dir(dataset)    # dir(dataset) Used to view all attributes/methods that allows to perform specific operation

# %%
dataset.columns   # View all the column names of dataset.
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
dataset["gender"].dtypes
# Out:
# dtype('O')

# %%
dataset["ssc_p"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # Logic to separate Quantitative and Qualitative Manually

# %%
for ColumnName in dataset.columns:
    print(ColumnName)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
if (dataset["ssc_p"].dtypes=="O"):
    print("Qual")
else:
    print("Quan")
# Out:
# Quan

# %% [markdown]
# Logic to separate Quantitative and Qualitative Automatically

# %%
#Creating a empty list and check the conditions using for loop
Quan=[]
Qual=[]
for ColumnName in dataset.columns:
    print(ColumnName)
    if (dataset[ColumnName].dtypes=="O"):
        print("Qual")
    else:
        print("Quan")
# Out:
# sl_no
# Quan
# gender
# Qual
# ssc_p
# Quan
# ssc_b
# Qual
# hsc_p
# Quan
# hsc_b
# Qual
# hsc_s
# Qual
# degree_p
# Quan
# degree_t
# Qual
# workex
# Qual
# etest_p
# Quan
# specialisation
# Qual
# mba_p
# Quan
# status
# Qual
# salary
# Quan

# %% [markdown]
# # Logic to separate Quan and Qual Automatically

# %%
#Using append() method - Appends a element to the end of the list

Quan=[]
Qual=[]
for ColumnName in dataset.columns:
    print(ColumnName)
    if (dataset[ColumnName].dtypes=="O"):  # "O" is Object Data type
        print("Qual")
        Qual.append(ColumnName)
    else:
        print("Quan")
        Quan.append(ColumnName)
# Out:
# sl_no
# Quan
# gender
# Qual
# ssc_p
# Quan
# ssc_b
# Qual
# hsc_p
# Quan
# hsc_b
# Qual
# hsc_s
# Qual
# degree_p
# Quan
# degree_t
# Qual
# workex
# Qual
# etest_p
# Quan
# specialisation
# Qual
# mba_p
# Quan
# status
# Qual
# salary
# Quan

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# # Logic to separate Quan and Qual Automatically using Function

# %%
def QuanQual(dataset):
    Quan=[]
    Qual=[]
    for ColumnName in dataset.columns:
        #print(ColumnName)
        if (dataset[ColumnName].dtypes=="O"):
            #print("Qual")
            Qual.append(ColumnName)
        else:
            #print("Quan")
            Quan.append(ColumnName)
    return Quan,Qual                 #Calling QuanQual() function.

# %%
QuanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
Quan, Qual = QuanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# # Measure of Central Tendency

# %%
round(dataset["ssc_p"].mean())
# Out:
# 67

# %%
int(dataset["ssc_p"].median())
# Out:
# 67

# %%
int(dataset["ssc_p"].mode()[0])
# Out:
# 62

# %%
dataset.describe()   # To view mean, median, mode.
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive = pd.DataFrame()  # Creates an empty table and assigned to variable descriptive

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"]) # Creates a table with only index.

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: [Mean, Median, Mode]

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"], columns=Quan)  # Now it creates a table of Index and Columns with NaN values.

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive.loc["hsc_p", "Median"]=0  # Assign values for a particular Row-index, column

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary  Median
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN     NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN     NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN     NaN
# hsc_p    NaN   NaN   NaN      NaN     NaN   NaN    NaN     0.0

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"], columns=Quan)
for ColumnName in Quan:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    NaN        NaN        NaN        NaN        NaN        NaN
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median            NaN
# Mode              NaN

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"], columns=Quan)
for ColumnName in Quan:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
    descriptive[ColumnName]["Median"]=dataset[ColumnName].median()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode              NaN

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"], columns=Quan)
for ColumnName in Quan:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
    descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
    descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# # Measure of location of data - Percentile

# %%
import numpy as np # numpy library is used in panda to retrieve the percentile for the dataset

# %%
np.percentile(dataset["ssc_p"],10)
# Out:
# np.float64(52.0)

# %%
float(np.percentile(dataset["ssc_p"], 10)) 

# np.percentile(column_data,percentile). This returns result without handling  missing values (Nan) 
# 10% of the data is within 52 score in SSC.
# we can calculate the percentile value for the 4 quadrant (25, 50, 75, 100)
# Out:
# 52.0

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%", "Q4:100"], columns=Quan)
for ColumnName in Quan:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
    descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
    descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    NaN        NaN        NaN        NaN        NaN        NaN
# Q2:50%    NaN        NaN        NaN        NaN        NaN        NaN
# Q3:75%    NaN        NaN        NaN        NaN        NaN        NaN
# Q4:100    NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0
# Q1:25%            NaN
# Q2:50%            NaN
# Q3:75%            NaN
# Q4:100            NaN

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%", "99%", "Q4:100%"], columns=Quan)
for ColumnName in Quan:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
    descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
    descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]
    descriptive[ColumnName]["Q1:25%"]=dataset.describe()[ColumnName]["25%"]
    descriptive[ColumnName]["Q2:50%"]=dataset.describe()[ColumnName]["50%"]
    descriptive[ColumnName]["Q3:75%"]=dataset.describe()[ColumnName]["75%"]
    descriptive[ColumnName]["99%"]=float(np.percentile(dataset[ColumnName],[99]))
    descriptive[ColumnName]["Q4:100%"]=dataset.describe()[ColumnName]["max"]

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# 99%                NaN
# Q4:100%       940000.0
